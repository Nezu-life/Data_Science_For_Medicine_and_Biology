# %% [markdown]
# <a href="https://colab.research.google.com/github/Nezu-life/Data_Science_For_Medicine_and_Biology/blob/main/Colab_Notebooks/Statistics_One_way_ANOVA_and_Posthoc_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Science for Medicine and Biology
#
# Nezu Life Sciences
#
# Feel free to modify, redistribute and above all,
# create something with this code.
#
# Tiago Lopes, PhD
# March 2024

import pandas as pd
from scipy.stats import dunnett
from scipy.stats import f_oneway
import matplotlib.pyplot as plt

# Load the dataset from the command line
fileName = "https://raw.githubusercontent.com/Nezu-life/Data_Science_For_Medicine_and_Biology/main/datasets/LDL_cholesterol_synthetic.csv"
ldl = pd.read_csv(fileName)

# Perform one-way ANOVA
F, p = f_oneway(ldl['Control'], ldl['Drug_1'], ldl['Drug_2'], ldl['Drug_3'])

print(f"The ANOVA F-statistic: {F:.2f}")
print(f"The ANOVA p-value: {p:.4f}")

print("")

# The Dunnett's test
res = dunnett(ldl['Drug_1'], ldl['Drug_2'], ldl['Drug_3'], control=ldl['Control'])

print(f"Drug #1 vs control = {res.pvalue[0]:.4f}")
print(f"Drug #2 vs control = {res.pvalue[1]:.4f}")
print(f"Drug #3 vs control = {res.pvalue[2]:.4f}")

# Make a boxplot of the groups

fig, ax = plt.subplots(1, 1)

ax.boxplot([ldl['Control'], ldl['Drug_1'], ldl['Drug_2'], ldl['Drug_3']])
ax.set_xticklabels(["Control", "Drug_1", "Drug_2", "Drug_3"])
ax.set_ylabel("LDL Cholesterol levels")
plt.show()
# Out:
# The ANOVA F-statistic: 113.22
# The ANOVA p-value: 0.0000
#
# Drug #1 vs control = 0.0000
# Drug #2 vs control = 0.0000
# Drug #3 vs control = 0.0000

# %%
from scipy.stats import tukey_hsd

# Load the dataset from the command line
fileName = "https://raw.githubusercontent.com/Nezu-life/Data_Science_For_Medicine_and_Biology/main/datasets/LDL_cholesterol_synthetic.csv"
ldl = pd.read_csv(fileName)

# Perform one-way ANOVA
F, p = f_oneway(ldl['Control'], ldl['Drug_1'], ldl['Drug_2'], ldl['Drug_3'])

print(f"The ANOVA F-statistic: {F:.2f}")
print(f"The ANOVA p-value: {p:.4f}")

print("")

# The Dunnett's test
res = tukey_hsd(ldl['Control'], ldl['Drug_1'], ldl['Drug_2'], ldl['Drug_3'])

print(res)

# Make a boxplot of the groups

fig, ax = plt.subplots(1, 1)

ax.boxplot([ldl['Control'], ldl['Drug_1'], ldl['Drug_2'], ldl['Drug_3']])
ax.set_xticklabels(["Control", "Drug_1", "Drug_2", "Drug_3"])
ax.set_ylabel("LDL Cholesterol levels")
plt.show()
# Out:
# The ANOVA F-statistic: 113.22
# The ANOVA p-value: 0.0000
#
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     42.300     0.000    28.454    56.146
#  (0 - 2)     81.100     0.000    67.254    94.946
#  (0 - 3)     81.100     0.000    67.254    94.946
#  (1 - 0)    -42.300     0.000   -56.146   -28.454
#  (1 - 2)     38.800     0.000    24.954    52.646
#  (1 - 3)     38.800     0.000    24.954    52.646
#  (2 - 0)    -81.100     0.000   -94.946   -67.254
#  (2 - 1)    -38.800     0.000   -52.646   -24.954
#  (2 - 3)      0.000     1.000   -13.846    13.846
#  (3 - 0)    -81.100     0.000   -94.946   -67.254
#  (3 - 1)    -38.800     0.000   -52.646   -24.954
#  (3 - 2)      0.000     1.000   -13.846    13.846
