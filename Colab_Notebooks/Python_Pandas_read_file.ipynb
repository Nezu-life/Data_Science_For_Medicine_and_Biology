# %%
# Data Science for Medicine and Biology
#
# Nezu Life Sciences
#
# Feel free to modify, redistribute and above all,
# create something with this code.
#
# Tiago Lopes, PhD
# March 2024

import pandas as pd

URL = "https://raw.githubusercontent.com/Nezu-life/Machine_Learning_Course_English/main/Intro_to_Python/datasets/HIV_incidence_rate.csv"

hiv = pd.read_csv(URL, sep="\t")

print(hiv.shape)
# Out:
# (135, 34)

# %%
hiv.head(10)
# Out:
#        Country    1990    1991    1992    1993    1994    1995    1996  \
# 0  Afghanistan  0.0272  0.0318  0.0380  0.0424  0.0485  0.0530  0.0566
# 1      Albania  0.0019  0.0024  0.0031  0.0040  0.0051  0.0065  0.0082
# 2      Algeria  0.0105  0.0117  0.0128  0.0141  0.0154  0.0169  0.0183
# 3       Angola  0.9741  1.1075  1.2396  1.3494  1.4942  1.6293  1.7249
# 4    Argentina  0.3045  0.3430  0.3612  0.3634  0.3560  0.3447  0.3334
# 5      Armenia  0.0002  0.0003  0.0006  0.0010  0.0017  0.0028  0.0047
# 6    Australia  0.0877  0.0758  0.0676  0.0622  0.0594  0.0585  0.0592
# 7   Azerbaijan  0.0085  0.0104  0.0147  0.0214  0.0318  0.0472  0.0675
# 8      Bahamas  2.5702  2.6127  2.5814  2.5006  2.3884  2.2600  2.1244
# 9   Bangladesh  0.0002  0.0003  0.0005  0.0007  0.0009  0.0011  0.0015
#
#      1997    1998  ...    2013    2014    2015    2016    2017    2018  \
# 0  0.0563  0.0625  ...  0.0610  0.0616  0.0605  0.0577  0.0543  0.0555
# ...

# %%
hiv.tail(5)
# Out:
#       Country       1990       1991       1992       1993       1994  \
# 130   Vietnam   0.047100   0.096100   0.174200   0.271900   0.358800
# 131     World   0.736156   0.801924   0.849180   0.872792   0.910705
# 132     Yemen   0.022900   0.024400   0.026000   0.027600   0.029000
# 133    Zambia  26.005600  26.402900  25.672800  24.813500  23.289400
# 134  Zimbabwe  50.113617  51.133945  49.104748  45.242090  40.517654
#
#           1995       1996       1997       1998  ...      2013      2014  \
# 130   0.407100   0.422000   0.426800   0.430500  ...  0.210600  0.201800
# 131   0.889509   0.862678   0.832071   0.786314  ...  0.431504  0.415911
# 132   0.030300   0.031400   0.032500   0.033600  ...  0.045200  0.045500
# 133  21.585100  20.416300  19.317900  18.262700  ...  9.670400  9.158500
# 134  35.657387  31.395390  27.228437  24.395160  ...  7.979178  7.176056
#
#          2015      2016      2017      2018      2019      2020      2021  \
# ...

# %%
hiv.dtypes
# Out:
# Country     object
# 1990       float64
# 1991       float64
# 1992       float64
# 1993       float64
# 1994       float64
# 1995       float64
# 1996       float64
# 1997       float64
# 1998       float64
# 1999       float64
# 2000       float64
# 2001       float64
# 2002       float64
# 2003       float64
# 2004       float64
# 2005       float64
# 2006       float64
# 2007       float64
# 2008       float64
# 2009       float64
# 2010       float64
# 2011       float64
# 2012       float64
# 2013       float64
# 2014       float64
# 2015       float64
# 2016       float64
# 2017       float64
# 2018       float64
# 2019       float64
# 2020       float64
# 2021       float64
# 2022       float64
# dtype: object

# %%
hiv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 34 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  135 non-null    object
#  1   1990     133 non-null    float64
#  2   1991     133 non-null    float64
#  3   1992     133 non-null    float64
#  4   1993     133 non-null    float64
#  5   1994     133 non-null    float64
#  6   1995     133 non-null    float64
#  7   1996     133 non-null    float64
#  8   1997     133 non-null    float64
#  9   1998     133 non-null    float64
#  10  1999     133 non-null    float64
#  11  2000     133 non-null    float64
#  12  2001     133 non-null    float64
#  13  2002     133 non-null    float64
#  14  2003     133 non-null    float64
#  15  2004     133 non-null    float64
#  16  2005     133 non-null    float64
#  17  2006     133 non-null    float64
#  18  2007     133 non-null    float64
#  19  2008     133 non-null    float64
# ...
